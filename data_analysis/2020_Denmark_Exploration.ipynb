# %% [markdown]
# # 2020 Denmark Data Exploration and Cleaning

# %%
import pandas as pd
import matplotlib.pyplot as plt
import plotly_express as px
import seaborn as sns

import warnings
warnings.simplefilter('ignore')
import statsmodels.formula.api as smf

# %% [markdown]
# ## Purpose of this notebook

# %% [markdown]
# - initial cleaning and look at raw data files for happiness ratings in 2020 for Denmark and COVID-19 cases in Denmark
# - create cleaned versions of files for analysis notebook

# %% [markdown]
# ## Load datasets into dataframes

# %%
denmark_hap = pd.read_csv('../data/raw_data/2020/denmark.csv')
covid_global=pd.read_csv('../data/raw_data/2020/covid19_cases_global.csv')

# %% [markdown]
# ## Start with Denmark dataset for happiness ratings

# %%
denmark_hap
# Out:
#        RecordNo           endtime    qweek  i1_health  i2_health  i7a_health  \
# 0             0  09/04/2020 10:42   week 1          0          3           1
# 1             1  09/04/2020 10:44   week 1          3          3           4
# 2             2  09/04/2020 10:44   week 1          2          2           3
# 3             3  09/04/2020 10:45   week 1          1          0           1
# 4             4  09/04/2020 10:46   week 1          5          5           5
# ...         ...               ...      ...        ...        ...         ...
# 16048     16048  16/11/2020 15:48  week 16          2          5           4
# 16049     16049  16/11/2020 15:50  week 16          1          9           1
# 16050     16050  16/11/2020 15:51  week 16          0          4           1
# 16051     16051  16/11/2020 15:52  week 16          2         50           2
# 16052     16052  16/11/2020 15:55  week 16          0          9           1
#
#                                                i3_health  \
# 0                                         No, I have not
# 1                                         No, I have not
# 2                                         No, I have not
# 3                                         No, I have not
# 4      Yes, and I have not received my results from t...
# ...                                                  ...
# 16048                                     No, I have not
# 16049                                     No, I have not
# 16050                                     No, I have not
# 16051                                     No, I have not
# 16052                                     No, I have not
#
#                            i4_health i5_health_1 i5_health_2  ... Soc2_6  \
# 0                  No, they have not          No          No  ...
# 1                  No, they have not          No          No  ...
# 2                  No, they have not          No          No  ...
# 3                  No, they have not          No          No  ...
# 4                                             No          No  ...
# ...                              ...         ...         ...  ...    ...
# 16048  Yes, and they tested negative          No          No  ...
# 16049              No, they have not          No          No  ...     No
# 16050              No, they have not          No          No  ...
# 16051  Yes, and they tested negative          No          No  ...
# 16052              No, they have not          No          No  ...
#
#       Soc2_open                  vac_1               vac_2  \
# 0
# 1
# 2
# 3
# 4
# ...         ...                    ...                 ...
# 16048    __NA__                      2  1 - Strongly agree
# 16049    __NA__                      2  1 - Strongly agree
# 16050    __NA__     1 - Strongly agree  1 - Strongly agree
# 16051    __NA__                      4                   3
# 16052    __NA__  5 – Strongly disagree                   3
#
#                       vac2_1              vac2_2              vac2_3  \
# 0
# 1
# 2
# 3
# 4
# ...                      ...                 ...                 ...
# 16048                      4                   2  1 - Strongly agree
# 16049                      2                   4                   2
# 16050                      4                   3                   4
# 16051  5 – Strongly disagree                   3                   2
# 16052                      2  1 - Strongly agree                   3
#
#                    vac2_4              vac2_5                 vac2_6
# 0
# 1
# 2
# 3
# 4
# ...                   ...                 ...                    ...
# 16048                   3                   3                      2
# 16049                   3                   2     1 - Strongly agree
# 16050  1 - Strongly agree  1 - Strongly agree     1 - Strongly agree
# 16051                   2                   3  5 – Strongly disagree
# 16052                   3  1 - Strongly agree  5 – Strongly disagree
#
# [16053 rows x 361 columns]

# %% [markdown]
# ## Selecting and renaming columns relevant for this data analysis

# %%
denmark_hap=denmark_hap[['RecordNo', 'endtime','region','qweek','i3_health','d1_health_12','age','gender','WCRex2','CORE_B2_4','cantril_ladder','PHQ4_1','PHQ4_2','PHQ4_3','PHQ4_4','WCRex1','r1_1','r1_7','ox3_1','ox3_2','ox3_3','ox3_6','ox5_2','ox6','w2','w3','w4_1','w4_2','w4_7','w4_8','w4_9','w9_1','w9_2']]

# %%
col_dict = {
    'RecordNo':'record_no',
    'endtime':'date',
    'qweek':'week',
    'i3_health':'covid_test',
    'd1_health_12':'mental_health_condition',
    'WCRex2':'confidence_NHS',
    'CORE_B2_4':'happiness_2wk_comparison',
    'cantril_ladder':'happiness_rating',
    'PHQ4_1':'little_interest',
    'PHQ4_2':'negative_feelings',
    'PHQ4_3':'anxiety',
    'PHQ4_4':'worry',
    'WCRex1':'gvt_rating',
    'r1_1':'perceptions_covid',
    'r1_7':'covid_effect',
    'ox3_1':'social_norms',
    'ox3_2':'social_expectations',
    'ox3_3':'appropriate_behaviors',
    'ox3_6':'follow_norms',
    'ox5_2':'trust_gvt',
    'ox6':'public_sector',
    'w2':'community_belonging',
    'w3':'belonging_change',
    'w4_1':'spoken_mental',
    'w4_2':'medication_mental',
    'w4_7':'seek_mental',
    'w4_8':'professional_mental',
    'w4_9':'readings_mental',
    'w9_1':'cheerful',
    'w9_2':'relaxed',}
denmark_hap = denmark_hap.rename(columns = col_dict)

# %%
denmark_hap
# Out:
#        record_no              date       region     week  \
# 0              0  09/04/2020 10:42  Nordjylland   week 1
# 1              1  09/04/2020 10:44   Syddanmark   week 1
# 2              2  09/04/2020 10:44  Midtjylland   week 1
# 3              3  09/04/2020 10:45  Midtjylland   week 1
# 4              4  09/04/2020 10:46  Nordjylland   week 1
# ...          ...               ...          ...      ...
# 16048      16048  16/11/2020 15:48  Midtjylland  week 16
# 16049      16049  16/11/2020 15:50  Midtjylland  week 16
# 16050      16050  16/11/2020 15:51   Syddanmark  week 16
# 16051      16051  16/11/2020 15:52     Sjælland  week 16
# 16052      16052  16/11/2020 15:55  Midtjylland  week 16
#
#                                               covid_test  \
# 0                                         No, I have not
# 1                                         No, I have not
# 2                                         No, I have not
# 3                                         No, I have not
# 4      Yes, and I have not received my results from t...
# ...                                                  ...
# 16048                                     No, I have not
# 16049                                     No, I have not
# 16050                                     No, I have not
# 16051                                     No, I have not
# 16052                                     No, I have not
#
#       mental_health_condition  age  gender               confidence_NHS  \
# 0                          No   25    Male
# 1                          No   42    Male
# 2                          No   63    Male
# 3                          No   30  Female
# 4                          No   30    Male
# ...                       ...  ...     ...                          ...
# 16048                      No   56    Male  A fair amount of confidence
# 16049                      No   68  Female          A lot of confidence
# 16050                      No   56  Female          A lot of confidence
# 16051                      No   20    Male          A lot of confidence
# 16052                      No   62  Female          A lot of confidence
#
#       happiness_2wk_comparison  ... public_sector community_belonging  \
# 0                               ...
# 1                               ...
# 2                               ...
# 3                               ...
# 4                               ...
# ...                        ...  ...           ...                 ...
# 16048                           ...
# 16049                           ...
# 16050                           ...
# 16051                           ...
# 16052                           ...
#
#       belonging_change spoken_mental medication_mental seek_mental  \
# 0
# 1
# 2
# 3
# 4
# ...                ...           ...               ...         ...
# 16048
# 16049
# 16050
# 16051
# 16052
#
#       professional_mental readings_mental cheerful relaxed
# 0
# 1
# 2
# 3
# 4
# ...                   ...             ...      ...     ...
# 16048
# 16049
# 16050
# 16051
# 16052
#
# [16053 rows x 33 columns]

# %% [markdown]
# ## Filtering columns further

# %%
cols_filter = ['date','week','region','mental_health_condition','age','gender','happiness_rating']
denmark_hap_filter=denmark_hap[cols_filter]
denmark_hap_filter
# Out:
#                    date     week       region mental_health_condition  age  \
# 0      09/04/2020 10:42   week 1  Nordjylland                      No   25
# 1      09/04/2020 10:44   week 1   Syddanmark                      No   42
# 2      09/04/2020 10:44   week 1  Midtjylland                      No   63
# 3      09/04/2020 10:45   week 1  Midtjylland                      No   30
# 4      09/04/2020 10:46   week 1  Nordjylland                      No   30
# ...                 ...      ...          ...                     ...  ...
# 16048  16/11/2020 15:48  week 16  Midtjylland                      No   56
# 16049  16/11/2020 15:50  week 16  Midtjylland                      No   68
# 16050  16/11/2020 15:51  week 16   Syddanmark                      No   56
# 16051  16/11/2020 15:52  week 16     Sjælland                      No   20
# 16052  16/11/2020 15:55  week 16  Midtjylland                      No   62
#
#        gender happiness_rating
# 0        Male
# 1        Male
# 2        Male
# 3      Female
# 4        Male
# ...       ...              ...
# 16048    Male                8
# 16049  Female                9
# 16050  Female                7
# 16051    Male                7
# 16052  Female                7
#
# [16053 rows x 7 columns]

# %%
## Since no happiness rating data available for week 1, drop rows corresponding to this timeframe
denmark_hap_filter.drop(denmark_hap_filter.loc[denmark_hap_filter['week']=='week 1'].index, inplace=True)

# %%
denmark_hap_filter['date'] = pd.to_datetime(denmark_hap_filter.date)
denmark_hap_filter['date'] = denmark_hap_filter['date'].dt.date

# %%
denmark_hap_filter['happiness_rating'] = denmark_hap_filter['happiness_rating'].astype(float)

# %%
denmark_hap_filter
# Out:
#              date     week       region mental_health_condition  age  gender  \
# 1006   2020-04-28   week 2  Nordjylland                      No   29  Female
# 1007   2020-04-28   week 2     Sjælland                      No   34    Male
# 1008   2020-04-28   week 2  Nordjylland                      No   33    Male
# 1009   2020-04-28   week 2   Syddanmark                      No   56  Female
# 1010   2020-04-28   week 2  Hovedstaden                      No   22  Female
# ...           ...      ...          ...                     ...  ...     ...
# 16048  2020-11-16  week 16  Midtjylland                      No   56    Male
# 16049  2020-11-16  week 16  Midtjylland                      No   68  Female
# 16050  2020-11-16  week 16   Syddanmark                      No   56  Female
# 16051  2020-11-16  week 16     Sjælland                      No   20    Male
# 16052  2020-11-16  week 16  Midtjylland                      No   62  Female
#
#        happiness_rating
# 1006                7.0
# 1007                5.0
# 1008                3.0
# 1009                8.0
# 1010                7.0
# ...                 ...
# 16048               8.0
# 16049               9.0
# 16050               7.0
# 16051               7.0
# 16052               7.0
#
# [15047 rows x 7 columns]

# %% [markdown]
# ## Exported to clean csv titled denmark_hap_cleaned.csv

# %%
# Making clean csv with these changes
denmark_hap_filter.to_csv('../data/cleaned_data/2020/denmark_hap_cleaned.csv')

# %% [markdown]
# ## Now looking at COVID-19 cases data

# %%
covid_global
# Out:
#     Province/State      Country/Region        Lat       Long  1/22/20  \
# 0              NaN         Afghanistan  33.939110  67.709953        0
# 1              NaN             Albania  41.153300  20.168300        0
# 2              NaN             Algeria  28.033900   1.659600        0
# 3              NaN             Andorra  42.506300   1.521800        0
# 4              NaN              Angola -11.202700  17.873900        0
# ..             ...                 ...        ...        ...      ...
# 266            NaN  West Bank and Gaza  31.952200  35.233200        0
# 267            NaN      Western Sahara  24.215500 -12.885800        0
# 268            NaN               Yemen  15.552727  48.516388        0
# 269            NaN              Zambia -13.133897  27.849332        0
# 270            NaN            Zimbabwe -19.015438  29.154857        0
#
#      1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  11/24/20  11/25/20  \
# 0          0        0        0        0        0  ...     45174     45384
# 1          0        0        0        0        0  ...     34300     34944
# 2          0        0        0        0        0  ...     77000     78025
# 3          0        0        0        0        0  ...      6351      6428
# 4          0        0        0        0        0  ...     14742     14821
# ..       ...      ...      ...      ...      ...  ...       ...       ...
# 266        0        0        0        0        0  ...     75007     76727
# 267        0        0        0        0        0  ...        10        10
# 268        0        0        0        0        0  ...      2114      2124
# 269        0        0        0        0        0  ...     17466     17535
# 270        0        0        0        0        0  ...      9398      9508
#
#      11/26/20  11/27/20  11/28/20  11/29/20  11/30/20  12/1/20  12/2/20  \
# 0       45600     45723     45844     46116     46274    46717    46980
# 1       35600     36245     36790     37625     38182    39014    39719
# 2       79110     80168     81212     82221     83199    84152    85084
# 3        6534      6610      6610      6712      6745     6790     6842
# 4       14920     15008     15087     15103     15139    15251    15319
# ..        ...       ...       ...       ...       ...      ...      ...
# 266     78493     80429     81890     83585     85647    88004    90192
# 267        10        10        10        10        10       10       10
# 268      2137      2148      2160      2177      2191     2197     2217
# 269     17553     17569     17589     17608     17647    17665    17700
# 270      9623      9714      9822      9822      9950    10129    10129
#
#      12/3/20
# 0      46718
# 1      40501
# 2      85927
# 3       6904
# 4      15361
# ..       ...
# 266    92708
# 267       10
# 268     2239
# 269    17730
# 270    10424
#
# [271 rows x 321 columns]

# %% [markdown]
# ## Selecting rows that correspond to Denmark and cleaning df

# %%
denmark_cov = covid_global.loc[covid_global['Country/Region']=='Denmark']
denmark_cov
# Out:
#     Province/State Country/Region      Lat     Long  1/22/20  1/23/20  \
# 101  Faroe Islands        Denmark  61.8926  -6.9118        0        0
# 102      Greenland        Denmark  71.7069 -42.6043        0        0
# 103            NaN        Denmark  56.2639   9.5018        0        0
#
#      1/24/20  1/25/20  1/26/20  1/27/20  ...  11/24/20  11/25/20  11/26/20  \
# 101        0        0        0        0  ...       500       500       500
# 102        0        0        0        0  ...        18        18        18
# 103        0        0        0        0  ...     73021     74204     75395
#
#      11/27/20  11/28/20  11/29/20  11/30/20  12/1/20  12/2/20  12/3/20
# 101       500       502       502       503      503      503      505
# 102        18        18        18        18       18       18       18
# 103     76718     78354     79352     80481    81949    83535    85140
#
# [3 rows x 321 columns]

# %%
date_cols = denmark_cov.columns[4:]
date_cols
# Out:
# Index(['1/22/20', '1/23/20', '1/24/20', '1/25/20', '1/26/20', '1/27/20',
#        '1/28/20', '1/29/20', '1/30/20', '1/31/20',
#        ...
#        '11/24/20', '11/25/20', '11/26/20', '11/27/20', '11/28/20', '11/29/20',
#        '11/30/20', '12/1/20', '12/2/20', '12/3/20'],
#       dtype='object', length=317)

# %%
denmark_cov = denmark_cov.melt(id_vars = denmark_cov.columns[:4],
                                    value_vars = date_cols,
                                    var_name = 'date',
                                    value_name = 'cases')
denmark_cov
# Out:
#     Province/State Country/Region      Lat     Long     date  cases
# 0    Faroe Islands        Denmark  61.8926  -6.9118  1/22/20      0
# 1        Greenland        Denmark  71.7069 -42.6043  1/22/20      0
# 2              NaN        Denmark  56.2639   9.5018  1/22/20      0
# 3    Faroe Islands        Denmark  61.8926  -6.9118  1/23/20      0
# 4        Greenland        Denmark  71.7069 -42.6043  1/23/20      0
# ..             ...            ...      ...      ...      ...    ...
# 946      Greenland        Denmark  71.7069 -42.6043  12/2/20     18
# 947            NaN        Denmark  56.2639   9.5018  12/2/20  83535
# 948  Faroe Islands        Denmark  61.8926  -6.9118  12/3/20    505
# 949      Greenland        Denmark  71.7069 -42.6043  12/3/20     18
# 950            NaN        Denmark  56.2639   9.5018  12/3/20  85140
#
# [951 rows x 6 columns]

# %%
denmark_cov['date']=pd.to_datetime(denmark_cov['date'])

# %% [markdown]
# ## Exported to clean csv titled denmark_covid.csv

# %%
# Making clean csv with these changes
denmark_cov.to_csv('../data/cleaned_data/2020/denmark_covid.csv')
