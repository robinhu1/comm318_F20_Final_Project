# %% [markdown]
# # 2020 India Data Exploration and Cleaning

# %%
import pandas as pd
import matplotlib.pyplot as plt
import plotly_express as px
import seaborn as sns

import warnings
warnings.simplefilter('ignore')
import statsmodels.formula.api as smf

# %% [markdown]
# ## Purpose of this notebook

# %% [markdown]
# - initial cleaning and look at raw data files for happiness ratings in 2020 for India and COVID-19 cases in India
# - create cleaned versions of files for analysis notebook

# %% [markdown]
# ## Load datasets into dataframes - India

# %%
india_hap = pd.read_csv('../data/raw_data/2020/india.csv')
covid_global=pd.read_csv('../data/raw_data/2020/covid19_cases_global.csv')

# %% [markdown]
# ## Start with India dataset for happiness

# %%
india_hap
# Out:
#        RecordNo           endtime  gender        state    qweek  i1_health  \
# 0            12  01/04/2020 16:13  Female      Gujarat   week 1          3
# 1            13  01/04/2020 16:26  Female    Karnataka   week 1          1
# 2            14  01/04/2020 16:29    Male    Karnataka   week 1          0
# 3            15  01/04/2020 16:30    Male  Maharashtra   week 1          2
# 4            16  01/04/2020 16:30  Female      Gujarat   week 1          5
# ...         ...               ...     ...          ...      ...        ...
# 16140     16152  20/09/2020 12:49  Female  West Bengal  week 16          2
# 16141     16153  20/09/2020 12:51  Female        Delhi  week 16          0
# 16142     16154  20/09/2020 13:29  Female        Assam  week 16          4
# 16143     16155  20/09/2020 14:00  Female    Jharkhand  week 16          3
# 16144     16156  20/09/2020 15:29  Female       Odisha  week 16          1
#
#        i2_health  i7a_health                   i3_health  \
# 0              2           0              No, I have not
# 1              2           0
# 2              0           0
# 3              0           0              No, I have not
# 4              4          24              No, I have not
# ...          ...         ...                         ...
# 16140          1           2              No, I have not
# 16141          0           0              No, I have not
# 16142          0           0  Yes, and I tested negative
# 16143          7           1              No, I have not
# 16144          2           5              No, I have not
#
#                            i4_health  ... w5_96 w5_99          w6  \
# 0                  No, they have not  ...
# 1                                     ...
# 2                                     ...
# 3                  No, they have not  ...
# 4                  No, they have not  ...
# ...                              ...  ...   ...   ...         ...
# 16140              No, they have not  ...    No    No         Yes
# 16141                                 ...                     Yes
# 16142  Yes, and they tested negative  ...              Don't Know
# 16143              No, they have not  ...                      No
# 16144                       Not sure  ...              Don't Know
#
#                         w7                        w9_1  \
# 0
# 1
# 2
# 3
# 4
# ...                    ...                         ...
# 16140                    4            Most of the time
# 16141           Don't know            Some of the time
# 16142     5 Agree strongly  Less than half of the time
# 16143  1 Disagree strongly                All the time
# 16144    Prefer not to say                  At no time
#
#                              w9_2                        w9_3  \
# 0
# 1
# 2
# 3
# 4
# ...                           ...                         ...
# 16140  More than half of the time            Most of the time
# 16141            Some of the time  Less than half of the time
# 16142            Some of the time  More than half of the time
# 16143                All the time                All the time
# 16144                All the time                  At no time
#
#                              w9_4                        w9_5  \
# 0
# 1
# 2
# 3
# 4
# ...                           ...                         ...
# 16140  More than half of the time  More than half of the time
# 16141            Some of the time  More than half of the time
# 16142            Most of the time                  At no time
# 16143                All the time            Most of the time
# 16144                  At no time  Less than half of the time
#
#                         disability
# 0
# 1
# 2
# 3
# 4
# ...                            ...
# 16140        Yes, limited a little
# 16141  Prefer not to say / skipped
# 16142                           No
# 16143                           No
# 16144  Prefer not to say / skipped
#
# [16145 rows x 334 columns]

# %% [markdown]
# ## Selecting and renaming columns relevant for analysis

# %%
india_hap_df =india_hap[['RecordNo', 'endtime','qweek','i3_health','d1_health_12','age','gender','WCRex2','CORE_B2_4','cantril_ladder','PHQ4_1','PHQ4_2','PHQ4_3','PHQ4_4','WCRex1','r1_1','r1_7','ox3_1','ox3_2','ox3_3','ox3_6','ox5_2','ox6','w2','w3','w4_1','w4_2','w4_7','w4_8','w4_9','w9_1','w9_2']]

# %%
col_dict = {
    'RecordNo':'record_no',
    'endtime':'date',
    'qweek':'week',
    'i3_health':'covid_test',
    'd1_health_12':'mental_health_condition',
    'WCRex2':'confidence_NHS',
    'CORE_B2_4':'happiness_2wk_comparison',
    'cantril_ladder':'happiness_rating',
    'PHQ4_1':'little_interest',
    'PHQ4_2':'negative_feelings',
    'PHQ4_3':'anxiety',
    'PHQ4_4':'worry',
    'WCRex1':'gvt_rating',
    'r1_1':'perceptions_covid',
    'r1_7':'covid_effect',
    'ox3_1':'social_norms',
    'ox3_2':'social_expectations',
    'ox3_3':'appropriate_behaviors',
    'ox3_6':'follow_norms',
    'ox5_2':'trust_gvt',
    'ox6':'public_sector',
    'w2':'community_belonging',
    'w3':'belonging_change',
    'w4_1':'spoken_mental',
    'w4_2':'medication_mental',
    'w4_7':'seek_mental',
    'w4_8':'professional_mental',
    'w4_9':'readings_mental',
    'w9_1':'cheerful',
    'w9_2':'relaxed',}
india_hap_df = india_hap_df.rename(columns = col_dict)

# %%
india_hap_df
# Out:
#        record_no              date     week                  covid_test  \
# 0             12  01/04/2020 16:13   week 1              No, I have not
# 1             13  01/04/2020 16:26   week 1
# 2             14  01/04/2020 16:29   week 1
# 3             15  01/04/2020 16:30   week 1              No, I have not
# 4             16  01/04/2020 16:30   week 1              No, I have not
# ...          ...               ...      ...                         ...
# 16140      16152  20/09/2020 12:49  week 16              No, I have not
# 16141      16153  20/09/2020 12:51  week 16              No, I have not
# 16142      16154  20/09/2020 13:29  week 16  Yes, and I tested negative
# 16143      16155  20/09/2020 14:00  week 16              No, I have not
# 16144      16156  20/09/2020 15:29  week 16              No, I have not
#
#       mental_health_condition  age  gender               confidence_NHS  \
# 0                               37  Female
# 1                               36  Female
# 2                               26    Male
# 3                          No   28    Male
# 4                          No   34  Female
# ...                       ...  ...     ...                          ...
# 16140                      No   55  Female  A fair amount of confidence
# 16141                      No   48  Female  A fair amount of confidence
# 16142                      No   50  Female  A fair amount of confidence
# 16143                      No   51  Female          A lot of confidence
# 16144                      No   59  Female                   Don't know
#
#       happiness_2wk_comparison happiness_rating  ... public_sector  \
# 0                                                ...
# 1                                                ...
# 2                                                ...
# 3                                                ...
# 4                                                ...
# ...                        ...              ...  ...           ...
# 16140                                         8  ...
# 16141                                         8  ...
# 16142                                         3  ...
# 16143                                        10  ...
# 16144                                         0  ...
#
#       community_belonging belonging_change spoken_mental medication_mental  \
# 0
# 1
# 2
# 3
# 4
# ...                   ...              ...           ...               ...
# 16140     Somewhat strong        Increased           Yes               Yes
# 16141     Somewhat strong        No change            No                No
# 16142     Somewhat strong        No change            No                No
# 16143         Very strong        Increased            No                No
# 16144           Very weak        No change            No                No
#
#       seek_mental professional_mental readings_mental  \
# 0
# 1
# 2
# 3
# 4
# ...           ...                 ...             ...
# 16140          No                  No              No
# 16141          No                  No             Yes
# 16142          No                  No              No
# 16143          No                  No              No
# 16144          No                  No              No
#
#                          cheerful                     relaxed
# 0
# 1
# 2
# 3
# 4
# ...                           ...                         ...
# 16140            Most of the time  More than half of the time
# 16141            Some of the time            Some of the time
# 16142  Less than half of the time            Some of the time
# 16143                All the time                All the time
# 16144                  At no time                All the time
#
# [16145 rows x 32 columns]

# %% [markdown]
# ## Filtering columns

# %%
cols_filter = ['date','week','mental_health_condition','age','gender','happiness_rating']
india_hap_filter=india_hap_df[cols_filter]
india_hap_filter
# Out:
#                    date     week mental_health_condition  age  gender  \
# 0      01/04/2020 16:13   week 1                           37  Female
# 1      01/04/2020 16:26   week 1                           36  Female
# 2      01/04/2020 16:29   week 1                           26    Male
# 3      01/04/2020 16:30   week 1                      No   28    Male
# 4      01/04/2020 16:30   week 1                      No   34  Female
# ...                 ...      ...                     ...  ...     ...
# 16140  20/09/2020 12:49  week 16                      No   55  Female
# 16141  20/09/2020 12:51  week 16                      No   48  Female
# 16142  20/09/2020 13:29  week 16                      No   50  Female
# 16143  20/09/2020 14:00  week 16                      No   51  Female
# 16144  20/09/2020 15:29  week 16                      No   59  Female
#
#       happiness_rating
# 0
# 1
# 2
# 3
# 4
# ...                ...
# 16140                8
# 16141                8
# 16142                3
# 16143               10
# 16144                0
#
# [16145 rows x 6 columns]

# %%
## No happiness rating data available for these weeks
india_hap_filter = india_hap_filter.drop(india_hap_filter[india_hap_filter.week.isin(['week 1', 'week 2','week 3','week 4'])].index)
india_hap_filter
# Out:
#                    date     week mental_health_condition  age  gender  \
# 4004   30/04/2020 16:38   week 5                      No   34  Female
# 4005   30/04/2020 16:38   week 5                      No   31  Female
# 4006   30/04/2020 16:43   week 5                      No   27  Female
# 4007   30/04/2020 16:43   week 5                      No   28  Female
# 4008   30/04/2020 16:44   week 5                      No   30    Male
# ...                 ...      ...                     ...  ...     ...
# 16140  20/09/2020 12:49  week 16                      No   55  Female
# 16141  20/09/2020 12:51  week 16                      No   48  Female
# 16142  20/09/2020 13:29  week 16                      No   50  Female
# 16143  20/09/2020 14:00  week 16                      No   51  Female
# 16144  20/09/2020 15:29  week 16                      No   59  Female
#
#       happiness_rating
# 4004                 5
# 4005                 5
# 4006                 8
# 4007                 5
# 4008                 8
# ...                ...
# 16140                8
# 16141                8
# 16142                3
# 16143               10
# 16144                0
#
# [12141 rows x 6 columns]

# %%
india_hap_filter['date'] = pd.to_datetime(india_hap_filter.date)
india_hap_filter['date'] = india_hap_filter['date'].dt.date

# %%
india_hap_filter['happiness_rating'] = india_hap_filter['happiness_rating'].astype(float)

# %%
india_hap_filter
# Out:
#              date     week mental_health_condition  age  gender  \
# 4004   2020-04-30   week 5                      No   34  Female
# 4005   2020-04-30   week 5                      No   31  Female
# 4006   2020-04-30   week 5                      No   27  Female
# 4007   2020-04-30   week 5                      No   28  Female
# 4008   2020-04-30   week 5                      No   30    Male
# ...           ...      ...                     ...  ...     ...
# 16140  2020-09-20  week 16                      No   55  Female
# 16141  2020-09-20  week 16                      No   48  Female
# 16142  2020-09-20  week 16                      No   50  Female
# 16143  2020-09-20  week 16                      No   51  Female
# 16144  2020-09-20  week 16                      No   59  Female
#
#        happiness_rating
# 4004                5.0
# 4005                5.0
# 4006                8.0
# 4007                5.0
# 4008                8.0
# ...                 ...
# 16140               8.0
# 16141               8.0
# 16142               3.0
# 16143              10.0
# 16144               0.0
#
# [12141 rows x 6 columns]

# %% [markdown]
# ## Exported to clean csv titled india_hap_cleaned.csv

# %%
# Making clean csv with these changes
india_hap_filter.to_csv('../data/cleaned_data/2020/india_hap_cleaned.csv')

# %% [markdown]
# ## Now looking at COVID-19 cases data- India

# %%
covid_global
# Out:
#     Province/State      Country/Region        Lat       Long  1/22/20  \
# 0              NaN         Afghanistan  33.939110  67.709953        0
# 1              NaN             Albania  41.153300  20.168300        0
# 2              NaN             Algeria  28.033900   1.659600        0
# 3              NaN             Andorra  42.506300   1.521800        0
# 4              NaN              Angola -11.202700  17.873900        0
# ..             ...                 ...        ...        ...      ...
# 266            NaN  West Bank and Gaza  31.952200  35.233200        0
# 267            NaN      Western Sahara  24.215500 -12.885800        0
# 268            NaN               Yemen  15.552727  48.516388        0
# 269            NaN              Zambia -13.133897  27.849332        0
# 270            NaN            Zimbabwe -19.015438  29.154857        0
#
#      1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  11/24/20  11/25/20  \
# 0          0        0        0        0        0  ...     45174     45384
# 1          0        0        0        0        0  ...     34300     34944
# 2          0        0        0        0        0  ...     77000     78025
# 3          0        0        0        0        0  ...      6351      6428
# 4          0        0        0        0        0  ...     14742     14821
# ..       ...      ...      ...      ...      ...  ...       ...       ...
# 266        0        0        0        0        0  ...     75007     76727
# 267        0        0        0        0        0  ...        10        10
# 268        0        0        0        0        0  ...      2114      2124
# 269        0        0        0        0        0  ...     17466     17535
# 270        0        0        0        0        0  ...      9398      9508
#
#      11/26/20  11/27/20  11/28/20  11/29/20  11/30/20  12/1/20  12/2/20  \
# 0       45600     45723     45844     46116     46274    46717    46980
# 1       35600     36245     36790     37625     38182    39014    39719
# 2       79110     80168     81212     82221     83199    84152    85084
# 3        6534      6610      6610      6712      6745     6790     6842
# 4       14920     15008     15087     15103     15139    15251    15319
# ..        ...       ...       ...       ...       ...      ...      ...
# 266     78493     80429     81890     83585     85647    88004    90192
# 267        10        10        10        10        10       10       10
# 268      2137      2148      2160      2177      2191     2197     2217
# 269     17553     17569     17589     17608     17647    17665    17700
# 270      9623      9714      9822      9822      9950    10129    10129
#
#      12/3/20
# 0      46718
# 1      40501
# 2      85927
# 3       6904
# 4      15361
# ..       ...
# 266    92708
# 267       10
# 268     2239
# 269    17730
# 270    10424
#
# [271 rows x 321 columns]

# %% [markdown]
# ## Selecting rows that correspond to India

# %%
india_cov = covid_global.loc[covid_global['Country/Region']=='India']
india_cov
# Out:
#     Province/State Country/Region        Lat      Long  1/22/20  1/23/20  \
# 145            NaN          India  20.593684  78.96288        0        0
#
#      1/24/20  1/25/20  1/26/20  1/27/20  ...  11/24/20  11/25/20  11/26/20  \
# 145        0        0        0        0  ...   9222216   9266705   9309787
#
#      11/27/20  11/28/20  11/29/20  11/30/20  12/1/20  12/2/20  12/3/20
# 145   9351109   9392919   9431691   9462809  9499413  9534964  9571559
#
# [1 rows x 321 columns]

# %%
date_cols = india_cov.columns[4:]
date_cols
# Out:
# Index(['1/22/20', '1/23/20', '1/24/20', '1/25/20', '1/26/20', '1/27/20',
#        '1/28/20', '1/29/20', '1/30/20', '1/31/20',
#        ...
#        '11/24/20', '11/25/20', '11/26/20', '11/27/20', '11/28/20', '11/29/20',
#        '11/30/20', '12/1/20', '12/2/20', '12/3/20'],
#       dtype='object', length=317)

# %%
india_cov = india_cov.melt(id_vars = india_cov.columns[:4],
                                    value_vars = date_cols,
                                    var_name = 'date',
                                    value_name = 'cases')

# %%
india_cov
# Out:
#     Province/State Country/Region        Lat      Long      date    cases
# 0              NaN          India  20.593684  78.96288   1/22/20        0
# 1              NaN          India  20.593684  78.96288   1/23/20        0
# 2              NaN          India  20.593684  78.96288   1/24/20        0
# 3              NaN          India  20.593684  78.96288   1/25/20        0
# 4              NaN          India  20.593684  78.96288   1/26/20        0
# ..             ...            ...        ...       ...       ...      ...
# 312            NaN          India  20.593684  78.96288  11/29/20  9431691
# 313            NaN          India  20.593684  78.96288  11/30/20  9462809
# 314            NaN          India  20.593684  78.96288   12/1/20  9499413
# 315            NaN          India  20.593684  78.96288   12/2/20  9534964
# 316            NaN          India  20.593684  78.96288   12/3/20  9571559
#
# [317 rows x 6 columns]

# %%
india_cov['date']=pd.to_datetime(india_cov['date'])

# %% [markdown]
# ## Exported to clean csv titled india_covid.csv

# %%
# Making clean csv with these changes
india_cov.to_csv('../data/cleaned_data/2020/india_covid.csv')
