# %% [markdown]
# # 2020 Malaysia Data Exploration and Cleaning

# %%
import pandas as pd
import matplotlib.pyplot as plt
import plotly_express as px
import seaborn as sns

import warnings
warnings.simplefilter('ignore')
import statsmodels.formula.api as smf

# %% [markdown]
# ## Purpose of this notebook

# %% [markdown]
# - initial cleaning and look at raw data files for happiness ratings in 2020 for Malaysia and COVID-19 cases in Malaysia
# - create cleaned versions of files for analysis notebook

# %% [markdown]
# ## Load datasets into dataframes

# %%
malaysia_hap = pd.read_csv('../data/raw_data/2020/malaysia.csv')
covid_global=pd.read_csv('../data/raw_data/2020/covid19_cases_global.csv')

# %% [markdown]
# ## Start with Malaysia dataset for happiness ratings

# %%
malaysia_hap
# Out:
#        RecordNo           endtime    qweek  i1_health  i2_health  i7a_health  \
# 0             0  09/04/2020 10:48   week 1          0          0           0
# 1             1  09/04/2020 10:49   week 1          0          5           1
# 2             2  09/04/2020 10:51   week 1          4          3           1
# 3             3  09/04/2020 10:55   week 1          8          5           1
# 4             4  09/04/2020 10:57   week 1          6          0           2
# ...         ...               ...      ...        ...        ...         ...
# 12128     12128  24/09/2020 01:50  week 12          8        100           2
# 12129     12129  24/09/2020 01:54  week 12          8          8           2
# 12130     12130  24/09/2020 02:01  week 12          3          2           3
# 12131     12131  24/09/2020 02:11  week 12          7          1           0
# 12132     12132  24/09/2020 02:42  week 12          3          3           2
#
#       i5a_health   i6_health i8_health i9_health  ... w5_99 w5_98          w6  \
# 0                                            Yes  ...
# 1                                            Yes  ...
# 2                                            Yes  ...
# 3             No  Frequently        No       Yes  ...
# 4                                            Yes  ...
# ...          ...         ...       ...       ...  ...   ...   ...         ...
# 12128        Yes   Sometimes                      ...                     Yes
# 12129                                             ...                      No
# 12130         No      Rarely                      ...                     Yes
# 12131                                             ...              Don't Know
# 12132                                             ...                      No
#
#                      w7                        w9_1  \
# 0
# 1
# 2
# 3
# 4
# ...                 ...                         ...
# 12128                 3            Some of the time
# 12129                 4                  At no time
# 12130  5 Agree strongly            Most of the time
# 12131                 2            Most of the time
# 12132                 4  Less than half of the time
#
#                              w9_2                        w9_3  \
# 0
# 1
# 2
# 3
# 4
# ...                           ...                         ...
# 12128            Some of the time            Some of the time
# 12129            Some of the time            Some of the time
# 12130            Most of the time            Most of the time
# 12131  More than half of the time            Most of the time
# 12132  Less than half of the time  More than half of the time
#
#                              w9_4                        w9_5  \
# 0
# 1
# 2
# 3
# 4
# ...                           ...                         ...
# 12128            Some of the time            Some of the time
# 12129                  At no time                  At no time
# 12130            Most of the time            Most of the time
# 12131  More than half of the time            Most of the time
# 12132  More than half of the time  More than half of the time
#
#                         disability
# 0
# 1
# 2
# 3
# 4
# ...                            ...
# 12128        Yes, limited a little
# 12129                           No
# 12130        Yes, limited a little
# 12131  Prefer not to say / skipped
# 12132  Prefer not to say / skipped
#
# [12133 rows x 324 columns]

# %% [markdown]
# ## Selecting and renaming columns relevant for this data analysis

# %%
malaysia_hap=malaysia_hap[['RecordNo', 'endtime','qweek','i3_health','d1_health_12','age','gender','CORE_B2_4','cantril_ladder','PHQ4_1','PHQ4_2','PHQ4_3','PHQ4_4','r1_1','r1_7','ox3_1','ox3_2','ox3_3','ox3_6','ox6','w2','w3','w4_1','w4_2','w4_7','w4_8','w4_9','w9_1','w9_2']]

# %%
col_dict = {
    'RecordNo':'record_no',
    'endtime':'date',
    'qweek':'week',
    'i3_health':'covid_test',
    'd1_health_12':'mental_health_condition',
    'CORE_B2_4':'happiness_2wk_comparison',
    'cantril_ladder':'happiness_rating',
    'PHQ4_1':'little_interest',
    'PHQ4_2':'negative_feelings',
    'PHQ4_3':'anxiety',
    'PHQ4_4':'worry',
    'r1_1':'perceptions_covid',
    'r1_7':'covid_effect',
    'ox3_1':'social_norms',
    'ox3_2':'social_expectations',
    'ox3_3':'appropriate_behaviors',
    'ox3_6':'follow_norms',
    'ox5_2':'trust_gvt',
    'ox6':'public_sector',
    'w2':'community_belonging',
    'w3':'belonging_change',
    'w4_1':'spoken_mental',
    'w4_2':'medication_mental',
    'w4_7':'seek_mental',
    'w4_8':'professional_mental',
    'w4_9':'readings_mental',
    'w9_1':'cheerful',
    'w9_2':'relaxed',}
malaysia_hap = malaysia_hap.rename(columns = col_dict)

# %%
malaysia_hap
# Out:
#        record_no              date     week                  covid_test  \
# 0              0  09/04/2020 10:48   week 1              No, I have not
# 1              1  09/04/2020 10:49   week 1              No, I have not
# 2              2  09/04/2020 10:51   week 1              No, I have not
# 3              3  09/04/2020 10:55   week 1  Yes, and I tested negative
# 4              4  09/04/2020 10:57   week 1              No, I have not
# ...          ...               ...      ...                         ...
# 12128      12128  24/09/2020 01:50  week 12              No, I have not
# 12129      12129  24/09/2020 01:54  week 12
# 12130      12130  24/09/2020 02:01  week 12  Yes, and I tested negative
# 12131      12131  24/09/2020 02:11  week 12              No, I have not
# 12132      12132  24/09/2020 02:42  week 12              No, I have not
#
#       mental_health_condition  age  gender happiness_2wk_comparison  \
# 0                          No   20  Female
# 1                          No   29    Male
# 2                          No   56    Male
# 3                          No   19    Male
# 4                          No   37    Male
# ...                       ...  ...     ...                      ...
# 12128                      No   19    Male
# 12129                      No   24    Male
# 12130                      No   21    Male
# 12131                      No   20    Male
# 12132                      No   24  Female
#
#       happiness_rating    little_interest  ... public_sector  \
# 0                                          ...
# 1                                          ...
# 2                                          ...
# 3                                          ...
# 4                                          ...
# ...                ...                ...  ...           ...
# 12128                5       Several days  ...
# 12129                5  Prefer not to say  ...
# 12130                9       Several days  ...
# 12131                8       Several days  ...
# 12132                5       Several days  ...
#
#       community_belonging belonging_change spoken_mental medication_mental  \
# 0
# 1
# 2
# 3
# 4
# ...                   ...              ...           ...               ...
# 12128       Somewhat weak        Increased            No                No
# 12129     Somewhat strong        Increased            No                No
# 12130         Very strong        Increased            No               Yes
# 12131           Very weak        No change            No                No
# 12132     Somewhat strong        Decreased            No                No
#
#       seek_mental professional_mental readings_mental  \
# 0
# 1
# 2
# 3
# 4
# ...           ...                 ...             ...
# 12128         Yes                  No             Yes
# 12129          No                  No              No
# 12130          No                  No              No
# 12131          No                  No              No
# 12132          No                  No              No
#
#                          cheerful                     relaxed
# 0
# 1
# 2
# 3
# 4
# ...                           ...                         ...
# 12128            Some of the time            Some of the time
# 12129                  At no time            Some of the time
# 12130            Most of the time            Most of the time
# 12131            Most of the time  More than half of the time
# 12132  Less than half of the time  Less than half of the time
#
# [12133 rows x 29 columns]

# %% [markdown]
# ## Filtering columns further

# %%
cols_filter = ['date','week','mental_health_condition','age','gender','happiness_rating']
malaysia_hap_filter=malaysia_hap[cols_filter]
malaysia_hap_filter
# Out:
#                    date     week mental_health_condition  age  gender  \
# 0      09/04/2020 10:48   week 1                      No   20  Female
# 1      09/04/2020 10:49   week 1                      No   29    Male
# 2      09/04/2020 10:51   week 1                      No   56    Male
# 3      09/04/2020 10:55   week 1                      No   19    Male
# 4      09/04/2020 10:57   week 1                      No   37    Male
# ...                 ...      ...                     ...  ...     ...
# 12128  24/09/2020 01:50  week 12                      No   19    Male
# 12129  24/09/2020 01:54  week 12                      No   24    Male
# 12130  24/09/2020 02:01  week 12                      No   21    Male
# 12131  24/09/2020 02:11  week 12                      No   20    Male
# 12132  24/09/2020 02:42  week 12                      No   24  Female
#
#       happiness_rating
# 0
# 1
# 2
# 3
# 4
# ...                ...
# 12128                5
# 12129                5
# 12130                9
# 12131                8
# 12132                5
#
# [12133 rows x 6 columns]

# %%
## Since no happiness rating data available for week 1, drop rows corresponding to this timeframe
malaysia_hap_filter.drop(malaysia_hap_filter.loc[malaysia_hap_filter['week']=='week 1'].index, inplace=True)

# %%
malaysia_hap_filter['date'] = pd.to_datetime(malaysia_hap_filter.date)
malaysia_hap_filter['date'] = malaysia_hap_filter['date'].dt.date

# %%
malaysia_hap_filter['happiness_rating'] = malaysia_hap_filter['happiness_rating'].astype(float)

# %%
malaysia_hap_filter
# Out:
#              date     week mental_health_condition  age  gender  \
# 1016   2020-04-28   week 2                      No   33  Female
# 1017   2020-04-28   week 2                      No   28    Male
# 1018   2020-04-28   week 2                      No   37    Male
# 1019   2020-04-28   week 2                      No   37  Female
# 1020   2020-04-28   week 2                      No   25  Female
# ...           ...      ...                     ...  ...     ...
# 12128  2020-09-24  week 12                      No   19    Male
# 12129  2020-09-24  week 12                      No   24    Male
# 12130  2020-09-24  week 12                      No   21    Male
# 12131  2020-09-24  week 12                      No   20    Male
# 12132  2020-09-24  week 12                      No   24  Female
#
#        happiness_rating
# 1016               10.0
# 1017                3.0
# 1018                1.0
# 1019                8.0
# 1020                5.0
# ...                 ...
# 12128               5.0
# 12129               5.0
# 12130               9.0
# 12131               8.0
# 12132               5.0
#
# [11117 rows x 6 columns]

# %% [markdown]
# ## Exported to clean csv titled malaysia_hap_cleaned.csv

# %%
# Making clean csv with these changes
malaysia_hap_filter.to_csv('../data/cleaned_data/2020/malaysia_hap_cleaned.csv')

# %% [markdown]
# ## Now looking at COVID-19 cases data

# %%
covid_global
# Out:
#     Province/State      Country/Region        Lat       Long  1/22/20  \
# 0              NaN         Afghanistan  33.939110  67.709953        0
# 1              NaN             Albania  41.153300  20.168300        0
# 2              NaN             Algeria  28.033900   1.659600        0
# 3              NaN             Andorra  42.506300   1.521800        0
# 4              NaN              Angola -11.202700  17.873900        0
# ..             ...                 ...        ...        ...      ...
# 266            NaN  West Bank and Gaza  31.952200  35.233200        0
# 267            NaN      Western Sahara  24.215500 -12.885800        0
# 268            NaN               Yemen  15.552727  48.516388        0
# 269            NaN              Zambia -13.133897  27.849332        0
# 270            NaN            Zimbabwe -19.015438  29.154857        0
#
#      1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  11/24/20  11/25/20  \
# 0          0        0        0        0        0  ...     45174     45384
# 1          0        0        0        0        0  ...     34300     34944
# 2          0        0        0        0        0  ...     77000     78025
# 3          0        0        0        0        0  ...      6351      6428
# 4          0        0        0        0        0  ...     14742     14821
# ..       ...      ...      ...      ...      ...  ...       ...       ...
# 266        0        0        0        0        0  ...     75007     76727
# 267        0        0        0        0        0  ...        10        10
# 268        0        0        0        0        0  ...      2114      2124
# 269        0        0        0        0        0  ...     17466     17535
# 270        0        0        0        0        0  ...      9398      9508
#
#      11/26/20  11/27/20  11/28/20  11/29/20  11/30/20  12/1/20  12/2/20  \
# 0       45600     45723     45844     46116     46274    46717    46980
# 1       35600     36245     36790     37625     38182    39014    39719
# 2       79110     80168     81212     82221     83199    84152    85084
# 3        6534      6610      6610      6712      6745     6790     6842
# 4       14920     15008     15087     15103     15139    15251    15319
# ..        ...       ...       ...       ...       ...      ...      ...
# 266     78493     80429     81890     83585     85647    88004    90192
# 267        10        10        10        10        10       10       10
# 268      2137      2148      2160      2177      2191     2197     2217
# 269     17553     17569     17589     17608     17647    17665    17700
# 270      9623      9714      9822      9822      9950    10129    10129
#
#      12/3/20
# 0      46718
# 1      40501
# 2      85927
# 3       6904
# 4      15361
# ..       ...
# 266    92708
# 267       10
# 268     2239
# 269    17730
# 270    10424
#
# [271 rows x 321 columns]

# %% [markdown]
# ## Selecting rows that correspond to Malaysia and cleaning df

# %%
malaysia_cov = covid_global.loc[covid_global['Country/Region']=='Malaysia']
malaysia_cov
# Out:
#     Province/State Country/Region       Lat        Long  1/22/20  1/23/20  \
# 173            NaN       Malaysia  4.210484  101.975766        0        0
#
#      1/24/20  1/25/20  1/26/20  1/27/20  ...  11/24/20  11/25/20  11/26/20  \
# 173        0        3        4        4  ...     58847     59817     60752
#
#      11/27/20  11/28/20  11/29/20  11/30/20  12/1/20  12/2/20  12/3/20
# 173     61861     63176     64485     65697    67169    68020    69095
#
# [1 rows x 321 columns]

# %%
date_cols = malaysia_cov.columns[4:]
date_cols
# Out:
# Index(['1/22/20', '1/23/20', '1/24/20', '1/25/20', '1/26/20', '1/27/20',
#        '1/28/20', '1/29/20', '1/30/20', '1/31/20',
#        ...
#        '11/24/20', '11/25/20', '11/26/20', '11/27/20', '11/28/20', '11/29/20',
#        '11/30/20', '12/1/20', '12/2/20', '12/3/20'],
#       dtype='object', length=317)

# %%
malaysia_cov = malaysia_cov.melt(id_vars = malaysia_cov.columns[:4],
                                    value_vars = date_cols,
                                    var_name = 'date',
                                    value_name = 'cases')
malaysia_cov
# Out:
#     Province/State Country/Region       Lat        Long      date  cases
# 0              NaN       Malaysia  4.210484  101.975766   1/22/20      0
# 1              NaN       Malaysia  4.210484  101.975766   1/23/20      0
# 2              NaN       Malaysia  4.210484  101.975766   1/24/20      0
# 3              NaN       Malaysia  4.210484  101.975766   1/25/20      3
# 4              NaN       Malaysia  4.210484  101.975766   1/26/20      4
# ..             ...            ...       ...         ...       ...    ...
# 312            NaN       Malaysia  4.210484  101.975766  11/29/20  64485
# 313            NaN       Malaysia  4.210484  101.975766  11/30/20  65697
# 314            NaN       Malaysia  4.210484  101.975766   12/1/20  67169
# 315            NaN       Malaysia  4.210484  101.975766   12/2/20  68020
# 316            NaN       Malaysia  4.210484  101.975766   12/3/20  69095
#
# [317 rows x 6 columns]

# %%
malaysia_cov['date']=pd.to_datetime(malaysia_cov['date'])

# %% [markdown]
# ## Exported to clean csv titled malaysia_covid.csv

# %%
# Making clean csv with these changes
malaysia_cov.to_csv('../data/cleaned_data/2020/malaysia_covid.csv')
