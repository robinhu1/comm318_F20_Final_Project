# %% [markdown]
# # 2020 Saudi Arabia Data Exploration and Cleaning

# %%
import pandas as pd
import matplotlib.pyplot as plt
import plotly_express as px
import seaborn as sns

import warnings
warnings.simplefilter('ignore')
import statsmodels.formula.api as smf

# %% [markdown]
# ## Purpose of this notebook

# %% [markdown]
# - initial cleaning and look at raw data files for happiness ratings in 2020 for Saudi Arabia and COVID-19 cases in Saudi Arabia
# - create cleaned versions of files for analysis notebook

# %% [markdown]
# ## Load datasets into dataframes

# %%
sa_hap = pd.read_csv('../data/raw_data/2020/saudi_arabia.csv')
covid_global=pd.read_csv('../data/raw_data/2020/covid19_cases_global.csv')

# %% [markdown]
# ## Start with Saudi Arabia dataset for happiness ratings

# %%
sa_hap
# Out:
#        RecordNo           endtime  age    qweek  i1_health  i2_health  \
# 0             0  08/04/2020 15:48   28   week 1          0          1
# 1             1  08/04/2020 15:50   36   week 1          0          0
# 2             2  08/04/2020 15:49   35   week 1          5          4
# 3             3  08/04/2020 15:50   26   week 1          2          1
# 4             4  08/04/2020 15:52   52   week 1          7          4
# ...         ...               ...  ...      ...        ...        ...
# 11445     11445  29/09/2020 09:59   22  week 12          9          7
# 11446     11446  29/09/2020 10:31   19  week 12          6          5
# 11447     11447  29/09/2020 10:38   55  week 12          4          0
# 11448     11448  29/09/2020 16:15   48  week 12          8         12
# 11449     11449  30/09/2020 14:33   57  week 12          2          7
#
#        i7a_health                   i3_health                      i4_health  \
# 0               1              No, I have not              No, they have not
# 1               1              No, I have not              No, they have not
# 2               3  Yes, and I tested positive  Yes, and they tested positive
# 3               1              No, I have not              No, they have not
# 4               1              No, I have not              No, they have not
# ...           ...                         ...                            ...
# 11445           1  Yes, and I tested positive  Yes, and they tested negative
# 11446           0              No, I have not              No, they have not
# 11447           1  Yes, and I tested negative  Yes, and they tested negative
# 11448           0              No, I have not              No, they have not
# 11449           6  Yes, and I tested negative  Yes, and they tested negative
#
#       i5_health_1  ... w5_99 w5_98          w6 w7                        w9_1  \
# 0              No  ...
# 1              No  ...
# 2              No  ...
# 3              No  ...
# 4              No  ...
# ...           ...  ...   ...   ...         ... ..                         ...
# 11445          No  ...                     Yes  3  More than half of the time
# 11446          No  ...              Don't Know  3            Some of the time
# 11447          No  ...                     Yes  4            Most of the time
# 11448          No  ...    No    No         Yes  4            Some of the time
# 11449          No  ...                     Yes  4            Most of the time
#
#                              w9_2                        w9_3  \
# 0
# 1
# 2
# 3
# 4
# ...                           ...                         ...
# 11445            Some of the time                All the time
# 11446  More than half of the time            Some of the time
# 11447  More than half of the time  More than half of the time
# 11448            Some of the time            Some of the time
# 11449  Less than half of the time                All the time
#
#                              w9_4              w9_5             disability
# 0
# 1
# 2
# 3
# 4
# ...                           ...               ...                    ...
# 11445  Less than half of the time        At no time  Yes, limited a little
# 11446            Some of the time  Some of the time                     No
# 11447            Most of the time      All the time                     No
# 11448                  At no time        At no time                     No
# 11449            Most of the time      All the time  Yes, limited a little
#
# [11450 rows x 300 columns]

# %% [markdown]
# ### Observations
#
# Lots of rows oh my 11450 and 300 columns. Most of them are not of interest for this analysis and have to refer to a codebook.

# %% [markdown]
# ## Selecting and renaming columns relevant for this data analysis

# %%
sa_hap=sa_hap[['RecordNo', 'endtime','qweek','i3_health','d1_health_12','age','gender','CORE_B2_4','cantril_ladder','PHQ4_1','PHQ4_2','PHQ4_3','PHQ4_4','r1_1','r1_7','ox3_1','ox3_2','ox3_3','ox3_6','ox6','w2','w3','w4_1','w4_2','w4_7','w4_8','w4_9','w9_1','w9_2']]

# %%
col_dict = {
    'RecordNo':'record_no',
    'endtime':'date',
    'qweek':'week',
    'i3_health':'covid_test',
    'd1_health_12':'mental_health_condition',
    'CORE_B2_4':'happiness_2wk_comparison',
    'cantril_ladder':'happiness_rating',
    'PHQ4_1':'little_interest',
    'PHQ4_2':'negative_feelings',
    'PHQ4_3':'anxiety',
    'PHQ4_4':'worry',
    'r1_1':'perceptions_covid',
    'r1_7':'covid_effect',
    'ox3_1':'social_norms',
    'ox3_2':'social_expectations',
    'ox3_3':'appropriate_behaviors',
    'ox3_6':'follow_norms',
    'ox5_2':'trust_gvt',
    'ox6':'public_sector',
    'w2':'community_belonging',
    'w3':'belonging_change',
    'w4_1':'spoken_mental',
    'w4_2':'medication_mental',
    'w4_7':'seek_mental',
    'w4_8':'professional_mental',
    'w4_9':'readings_mental',
    'w9_1':'cheerful',
    'w9_2':'relaxed',}
sa_hap = sa_hap.rename(columns = col_dict)

# %%
sa_hap
# Out:
#        record_no              date     week                  covid_test  \
# 0              0  08/04/2020 15:48   week 1              No, I have not
# 1              1  08/04/2020 15:50   week 1              No, I have not
# 2              2  08/04/2020 15:49   week 1  Yes, and I tested positive
# 3              3  08/04/2020 15:50   week 1              No, I have not
# 4              4  08/04/2020 15:52   week 1              No, I have not
# ...          ...               ...      ...                         ...
# 11445      11445  29/09/2020 09:59  week 12  Yes, and I tested positive
# 11446      11446  29/09/2020 10:31  week 12              No, I have not
# 11447      11447  29/09/2020 10:38  week 12  Yes, and I tested negative
# 11448      11448  29/09/2020 16:15  week 12              No, I have not
# 11449      11449  30/09/2020 14:33  week 12  Yes, and I tested negative
#
#       mental_health_condition  age  gender happiness_2wk_comparison  \
# 0                          No   28    Male
# 1                          No   36    Male
# 2                          No   35    Male
# 3                          No   26  Female
# 4                          No   52    Male
# ...                       ...  ...     ...                      ...
# 11445                      No   22  Female
# 11446                      No   19  Female
# 11447                      No   55  Female
# 11448                      No   48  Female
# 11449                      No   57  Female
#
#       happiness_rating   little_interest  ... public_sector  \
# 0                                         ...
# 1                                         ...
# 2                                         ...
# 3                                         ...
# 4                                         ...
# ...                ...               ...  ...           ...
# 11445                7      Several days  ...
# 11446                5  Nearly every day  ...
# 11447                7        Not at all  ...
# 11448                4      Several days  ...
# 11449                8        Not at all  ...
#
#       community_belonging belonging_change spoken_mental medication_mental  \
# 0
# 1
# 2
# 3
# 4
# ...                   ...              ...           ...               ...
# 11445       Somewhat weak        Increased            No                No
# 11446           Very weak        No change            No                No
# 11447         Very strong        No change            No                No
# 11448       Somewhat weak        Decreased           Yes               Yes
# 11449         Very strong        Decreased            No                No
#
#       seek_mental professional_mental readings_mental  \
# 0
# 1
# 2
# 3
# 4
# ...           ...                 ...             ...
# 11445          No                  No              No
# 11446          No                  No             Yes
# 11447          No                  No              No
# 11448          No                  No              No
# 11449          No                  No              No
#
#                          cheerful                     relaxed
# 0
# 1
# 2
# 3
# 4
# ...                           ...                         ...
# 11445  More than half of the time            Some of the time
# 11446            Some of the time  More than half of the time
# 11447            Most of the time  More than half of the time
# 11448            Some of the time            Some of the time
# 11449            Most of the time  Less than half of the time
#
# [11450 rows x 29 columns]

# %% [markdown]
# ## Filtering columns further

# %%
cols_filter = ['date','week','mental_health_condition','age','gender','happiness_rating']
sa_hap_filter=sa_hap[cols_filter]
sa_hap_filter
# Out:
#                    date     week mental_health_condition  age  gender  \
# 0      08/04/2020 15:48   week 1                      No   28    Male
# 1      08/04/2020 15:50   week 1                      No   36    Male
# 2      08/04/2020 15:49   week 1                      No   35    Male
# 3      08/04/2020 15:50   week 1                      No   26  Female
# 4      08/04/2020 15:52   week 1                      No   52    Male
# ...                 ...      ...                     ...  ...     ...
# 11445  29/09/2020 09:59  week 12                      No   22  Female
# 11446  29/09/2020 10:31  week 12                      No   19  Female
# 11447  29/09/2020 10:38  week 12                      No   55  Female
# 11448  29/09/2020 16:15  week 12                      No   48  Female
# 11449  30/09/2020 14:33  week 12                      No   57  Female
#
#       happiness_rating
# 0
# 1
# 2
# 3
# 4
# ...                ...
# 11445                7
# 11446                5
# 11447                7
# 11448                4
# 11449                8
#
# [11450 rows x 6 columns]

# %%
## Since no happiness rating data available for week 1, drop rows corresponding to this timeframe
sa_hap_filter.drop(sa_hap_filter.loc[sa_hap_filter['week']=='week 1'].index, inplace=True)

# %%
sa_hap_filter['date'] = pd.to_datetime(sa_hap_filter.date)
sa_hap_filter['date'] = sa_hap_filter['date'].dt.date

# %%
sa_hap_filter['happiness_rating'] = sa_hap_filter['happiness_rating'].astype(float)

# %%
sa_hap_filter
# Out:
#              date     week mental_health_condition  age  gender  \
# 940    2020-04-28   week 2                      No   30    Male
# 941    2020-04-28   week 2                      No   40  Female
# 942    2020-04-28   week 2                      No   53    Male
# 943    2020-04-28   week 2                      No   35    Male
# 944    2020-04-28   week 2                      No   33    Male
# ...           ...      ...                     ...  ...     ...
# 11445  2020-09-29  week 12                      No   22  Female
# 11446  2020-09-29  week 12                      No   19  Female
# 11447  2020-09-29  week 12                      No   55  Female
# 11448  2020-09-29  week 12                      No   48  Female
# 11449  2020-09-30  week 12                      No   57  Female
#
#        happiness_rating
# 940                 7.0
# 941                10.0
# 942                 6.0
# 943                 7.0
# 944                 6.0
# ...                 ...
# 11445               7.0
# 11446               5.0
# 11447               7.0
# 11448               4.0
# 11449               8.0
#
# [10510 rows x 6 columns]

# %% [markdown]
# ## Exported to clean csv titled saudi_arabia_hap_cleaned.csv

# %%
# Making clean csv with these changes
sa_hap_filter.to_csv('../data/cleaned_data/2020/saudi_arabia_hap_cleaned.csv')

# %% [markdown]
# ## Now looking at COVID-19 cases data

# %%
covid_global
# Out:
#     Province/State      Country/Region        Lat       Long  1/22/20  \
# 0              NaN         Afghanistan  33.939110  67.709953        0
# 1              NaN             Albania  41.153300  20.168300        0
# 2              NaN             Algeria  28.033900   1.659600        0
# 3              NaN             Andorra  42.506300   1.521800        0
# 4              NaN              Angola -11.202700  17.873900        0
# ..             ...                 ...        ...        ...      ...
# 266            NaN  West Bank and Gaza  31.952200  35.233200        0
# 267            NaN      Western Sahara  24.215500 -12.885800        0
# 268            NaN               Yemen  15.552727  48.516388        0
# 269            NaN              Zambia -13.133897  27.849332        0
# 270            NaN            Zimbabwe -19.015438  29.154857        0
#
#      1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  11/24/20  11/25/20  \
# 0          0        0        0        0        0  ...     45174     45384
# 1          0        0        0        0        0  ...     34300     34944
# 2          0        0        0        0        0  ...     77000     78025
# 3          0        0        0        0        0  ...      6351      6428
# 4          0        0        0        0        0  ...     14742     14821
# ..       ...      ...      ...      ...      ...  ...       ...       ...
# 266        0        0        0        0        0  ...     75007     76727
# 267        0        0        0        0        0  ...        10        10
# 268        0        0        0        0        0  ...      2114      2124
# 269        0        0        0        0        0  ...     17466     17535
# 270        0        0        0        0        0  ...      9398      9508
#
#      11/26/20  11/27/20  11/28/20  11/29/20  11/30/20  12/1/20  12/2/20  \
# 0       45600     45723     45844     46116     46274    46717    46980
# 1       35600     36245     36790     37625     38182    39014    39719
# 2       79110     80168     81212     82221     83199    84152    85084
# 3        6534      6610      6610      6712      6745     6790     6842
# 4       14920     15008     15087     15103     15139    15251    15319
# ..        ...       ...       ...       ...       ...      ...      ...
# 266     78493     80429     81890     83585     85647    88004    90192
# 267        10        10        10        10        10       10       10
# 268      2137      2148      2160      2177      2191     2197     2217
# 269     17553     17569     17589     17608     17647    17665    17700
# 270      9623      9714      9822      9822      9950    10129    10129
#
#      12/3/20
# 0      46718
# 1      40501
# 2      85927
# 3       6904
# 4      15361
# ..       ...
# 266    92708
# 267       10
# 268     2239
# 269    17730
# 270    10424
#
# [271 rows x 321 columns]

# %% [markdown]
# ## Selecting rows that correspond to Saudi Arabia and cleaning df

# %%
sa_cov = covid_global.loc[covid_global['Country/Region']=='Saudi Arabia']
sa_cov
# Out:
#     Province/State Country/Region        Lat       Long  1/22/20  1/23/20  \
# 218            NaN   Saudi Arabia  23.885942  45.079162        0        0
#
#      1/24/20  1/25/20  1/26/20  1/27/20  ...  11/24/20  11/25/20  11/26/20  \
# 218        0        0        0        0  ...    355741    356067    356389
#
#      11/27/20  11/28/20  11/29/20  11/30/20  12/1/20  12/2/20  12/3/20
# 218    356691    356911    357128    357360   357623   357872   358102
#
# [1 rows x 321 columns]

# %%
date_cols = sa_cov.columns[4:]
date_cols
# Out:
# Index(['1/22/20', '1/23/20', '1/24/20', '1/25/20', '1/26/20', '1/27/20',
#        '1/28/20', '1/29/20', '1/30/20', '1/31/20',
#        ...
#        '11/24/20', '11/25/20', '11/26/20', '11/27/20', '11/28/20', '11/29/20',
#        '11/30/20', '12/1/20', '12/2/20', '12/3/20'],
#       dtype='object', length=317)

# %%
sa_cov = sa_cov.melt(id_vars = sa_cov.columns[:4],
                                    value_vars = date_cols,
                                    var_name = 'date',
                                    value_name = 'cases')
sa_cov
# Out:
#     Province/State Country/Region        Lat       Long      date   cases
# 0              NaN   Saudi Arabia  23.885942  45.079162   1/22/20       0
# 1              NaN   Saudi Arabia  23.885942  45.079162   1/23/20       0
# 2              NaN   Saudi Arabia  23.885942  45.079162   1/24/20       0
# 3              NaN   Saudi Arabia  23.885942  45.079162   1/25/20       0
# 4              NaN   Saudi Arabia  23.885942  45.079162   1/26/20       0
# ..             ...            ...        ...        ...       ...     ...
# 312            NaN   Saudi Arabia  23.885942  45.079162  11/29/20  357128
# 313            NaN   Saudi Arabia  23.885942  45.079162  11/30/20  357360
# 314            NaN   Saudi Arabia  23.885942  45.079162   12/1/20  357623
# 315            NaN   Saudi Arabia  23.885942  45.079162   12/2/20  357872
# 316            NaN   Saudi Arabia  23.885942  45.079162   12/3/20  358102
#
# [317 rows x 6 columns]

# %%
sa_cov['date']=pd.to_datetime(sa_cov['date'])

# %% [markdown]
# ## Exported to clean csv titled sa_covid.csv

# %%
# Making clean csv with these changes
sa_cov.to_csv('../data/cleaned_data/2020/sa_covid.csv')
